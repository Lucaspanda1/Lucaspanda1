# %% [markdown]
# Automação de processos

# %%
import yfinance
import pyautogui
import pyperclip
import time 

ticker = input("digite o codigo d ação: ")

dados = yfinance.Ticker(ticker).history("6mo")
fechamento = dados.Close
maxima = round(fechamento.max(),2)
minima = round(fechamento.min(),2)
dia_atual = round(fechamento[-1],2)
print(maxima)
print(minima)
print(dia_atual)


pyautogui.pause = 2
pyautogui.hotkey("crtl", "t")
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")
pyautogui.click(x=2029, y=221)
pyperclip.copy("contato.lucaspanda@gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")
pyperclip.copycontato.lucaspanda@gmail.com  Analise e investimento  
Prezado Gestor, 
Seguem as analises diarias da ação PETR4.SA referentes aos ultimos seis meses.
cotação atual R$37.85
Cotação máxima R$38.52
cotação minima R$20.49

Qualquer duvida, estou a disposição
("Analise e investimento")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")
mensagem = f"""
Prezado Gestor, 
Seguem as analises diarias da ação {ticker} referentes aos ultimos seis meses.
cotação atual R${dia_atual}
Cotação máxima R${maxima}
cotação minima R${minima}

Qualquer duvida, estou a disposição
"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=3080, y=1034)
# Out:
# C:\Users\Silvia\AppData\Local\Temp\ipykernel_2272\2118198208.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dia_atual = round(fechamento[-1],2)
# 38.52
# 20.49
# 37.85
